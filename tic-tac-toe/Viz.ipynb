# %%
import matplotlib.pyplot as plot
import numpy as np

# %%
data = np.genfromtxt('dense.csv', delimiter=',', names=['winner', 'invalids'])

# %%
data[np.isnan(data['winner']) == False]
# Out:
# array([( 1., 1.), (-1., 0.), ( 1., 2.), ..., (-1., 0.), (-1., 2.),
#        (-1., 0.)], dtype=[('winner', '<f8'), ('invalids', '<f8')])

# %%
plot.plot(data['invalids'])

# %%
plot.plot(data['winner'], 'ro')
